# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %pip install -q https://github.com/nolanaatama/xformers-wheels/releases/download/xformers/xformers-0.0.15.dev0+4c06c79.d20221205-cp38-cp38-linux_x86_64.whl
# !curl -Lo samdoesartsJH.ckpt https://huggingface.co/nolanaatama/jh-sda/resolve/main/model.ckpt
# !mv "/content/samdoesartsJH.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"
# %cd /content/stable-diffusion-webui
# !COMMANDLINE_ARGS="--share --gradio-debug --medvram --disable-safe-unpickle --xformers" REQS_FILE="requirements.txt" python launch.py

# %% [markdown]
# # 📚 GitHub for more: [_@nolanaatama_](https://github.com/nolanaatama)
# # 📦 Repo: [Github](https://github.com/nolanaatama/sd-samdoesarts-colab)
#
# # 🎁 What Model Do? [SamDoesArt JH](https://huggingface.co/nolanaatama/jh-sda/)
